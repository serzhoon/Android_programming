# %% [markdown]
# <a href="https://colab.research.google.com/github/serzhoon/Android_programming/blob/main/lab02_HBase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Отчёт по лабораторной работе на тему: HBase

# %% [markdown]
# Выполнил студент группы ПИН-Б-З-22-1

# %% [markdown]
# Гадиян Сергей Гариевич
